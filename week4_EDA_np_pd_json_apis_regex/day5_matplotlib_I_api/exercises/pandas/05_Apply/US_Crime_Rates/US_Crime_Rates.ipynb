# %% [markdown]
# # United States - Crime Rates - 1960 - 2014

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called crime.

# %%
crime = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv", parse_dates=["Year"])
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
# Year                  55 non-null datetime64[ns]
# Population            55 non-null int64
# Total                 55 non-null int64
# Violent               55 non-null int64
# Property              55 non-null int64
# Murder                55 non-null int64
# Forcible_Rape         55 non-null int64
# Robbery               55 non-null int64
# Aggravated_assault    55 non-null int64
# Burglary              55 non-null int64
# Larceny_Theft         55 non-null int64
# Vehicle_Theft         55 non-null int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.3 KB

# %%
crime.index.values[0]
# Out:
# numpy.datetime64('1960-01-01T00:00:00.000000000')

# %% [markdown]
# ### Step 4. What is the type of the columns?

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55 entries, 1960 to 2014
# Data columns (total 11 columns):
# Population            55 non-null int64
# Total                 55 non-null int64
# Violent               55 non-null int64
# Property              55 non-null int64
# Murder                55 non-null int64
# Forcible_Rape         55 non-null int64
# Robbery               55 non-null int64
# Aggravated_assault    55 non-null int64
# Burglary              55 non-null int64
# Larceny_Theft         55 non-null int64
# Vehicle_Theft         55 non-null int64
# dtypes: int64(11)
# memory usage: 7.7 KB

# %% [markdown]
# ##### Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
#
# ### Step 5. Convert the type of the column Year to datetime64

# %% [markdown]
# ### Step 6. Set the Year column as the index of the dataframe

# %%
crime.set_index("Year", inplace=True)

# %% [markdown]
# ### Step 7. Delete the Total column

# %%
# Out:
#             Population  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960-01-01   179323175   288460   3095700    9110          17190   107840
# 1961-01-01   182992000   289390   3198600    8740          17220   106670
# 1962-01-01   185771000   301510   3450700    8530          17550   110860
# 1963-01-01   188483000   316970   3792500    8640          17650   116470
# 1964-01-01   191141000   364220   4200400    9360          21420   130390
#
#             Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1960-01-01              154320    912100        1855400         328200
# 1961-01-01              156760    949600        1913000         336000
# 1962-01-01              164570    994300        2089600         366800
# 1963-01-01              174210   1086400        2297800         408300
# 1964-01-01              203050   1213200        2514400         472800

# %% [markdown]
# ### Step 8. Group the year by decades and sum the values
#
# #### Pay attention to the Population column number, summing this column is a mistake

# %%
crime.plot()

# %%
crime3 = crime.drop(["Population"], axis=1)
crime3.plot()

# %%
crime.index
# Out:
# DatetimeIndex(['1960-01-01', '1961-01-01', '1962-01-01', '1963-01-01',
#                '1964-01-01', '1965-01-01', '1966-01-01', '1967-01-01',
#                '1968-01-01', '1969-01-01', '1970-01-01', '1971-01-01',
#                '1972-01-01', '1973-01-01', '1974-01-01', '1975-01-01',
#                '1976-01-01', '1977-01-01', '1978-01-01', '1979-01-01',
#                '1980-01-01', '1981-01-01', '1982-01-01', '1983-01-01',
#                '1984-01-01', '1985-01-01', '1986-01-01', '1987-01-01',
#                '1988-01-01', '1989-01-01', '1990-01-01', '1991-01-01',
#                '1992-01-01', '1993-01-01', '1994-01-01', '1995-01-01',
#                '1996-01-01', '1997-01-01', '1998-01-01', '1999-01-01',
#                '2000-01-01', '2001-01-01', '2002-01-01', '2003-01-01',
#                '2004-01-01', '2005-01-01', '2006-01-01', '2007-01-01',
#                '2008-01-01', '2009-01-01', '2010-01-01', '2011-01-01',
# ...

# %%
crime2 = crime.resample('10A').sum()
crime2
# Out:
#             Population      Total   Violent   Property  Murder  Forcible_Rape  \
# Year
# 1960-12-31   179323175    3384200    288460    3095700    9110          17190
# 1970-12-31  1938965298   54009700   4585290   49424400  113070         257520
# 1980-12-31  2143307264  106301900  10213630   96088300  199270         599570
# 1990-12-31  2394730678  132190669  14549938  117640700  206839         885209
# 2000-12-31  2645537291  133714618  17132404  116580585  203810         986445
# 2010-12-31  2975877430  113767845  13793818   99874408  162254         917914
# 2020-12-31  1260816088   39804094   4820769   34983325   58095         335466
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-12-31   107840              154320    912100        1855400
# 1970-12-31  1875530             2339170  14614000       28918100
# 1980-12-31  4375000             5039800  30076200       56068900
# 1990-12-31  5456539             8001340  32352194       72849053
# ...

# %%
crime2.plot()

# %%
crime2.drop(["Population"], inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-109ec6578c4c> in <module>
# ----> 1 crime2.drop(["Population"], inplace=True, axis=1)
#       2 crime2
#
# Z:\Data_Science\Software\Python\Python_3.6.4\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4115             level=level,
#    4116             inplace=inplace,
# -> 4117             errors=errors,
#    4118         )
#    4119
#
# Z:\Data_Science\Software\Python\Python_3.6.4\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
crime2
# Out:
#                 Total   Violent   Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960-12-31    3384200    288460    3095700    9110          17190   107840
# 1970-12-31   54009700   4585290   49424400  113070         257520  1875530
# 1980-12-31  106301900  10213630   96088300  199270         599570  4375000
# 1990-12-31  132190669  14549938  117640700  206839         885209  5456539
# 2000-12-31  133714618  17132404  116580585  203810         986445  5517676
# 2010-12-31  113767845  13793818   99874408  162254         917914  4191439
# 2020-12-31   39804094   4820769   34983325   58095         335466  1380720
#
#             Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1960-12-31              154320    912100        1855400         328200
# 1970-12-31             2339170  14614000       28918100        5892300
# 1980-12-31             5039800  30076200       56068900        9943200
# 1990-12-31             8001340  32352194       72849053       12439611
# ...

# %%
crime2.plot()

# %% [markdown]
# ### Step 9. What is the most dangerous decade to live in the US?

# %%
# Out:
# Population            2010
# Violent               1990
# Property              1990
# Murder                1990
# Forcible_Rape         1990
# Robbery               1990
# Aggravated_assault    1990
# Burglary              1980
# Larceny_Theft         1990
# Vehicle_Theft         1990
# dtype: int64
